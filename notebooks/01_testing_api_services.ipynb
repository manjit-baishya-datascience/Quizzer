# %% [markdown]
# # **Testing the `NVIDIA` LLM API Service**
# ---

# %% [markdown]
# ## **Importing libraries**

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %% [markdown]
# ## **Getting data from `env` file**

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## **Declaring NVIDIA Client**

# %%
client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = os.environ.get("NVIDIA_API_KEY")
)

# %% [markdown]
# ## **Testing `API` Response**

# %%
completion = client.chat.completions.create(
  model="deepseek-ai/deepseek-v4-pro-0813",
  messages=[{"role":"user","content":"Write a limerick about the wonders of GPU computing."}],
  temperature=1,
  top_p=0.95,
  max_tokens=16384,
  seed=42,
  extra_body={"chat_template_kwargs":{"thinking":False}},
  stream=False
)

print(completion.choices[0].message.content)
# Out:
# A graphics card, once just for the show,
# Found a calling where parallel flows.
# With cores by the thousand,
# It crunches and pounds, and
# Makes teraflop miracles grow.
